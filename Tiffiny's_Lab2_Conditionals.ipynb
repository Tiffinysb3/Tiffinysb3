# %% [markdown]
# <a href="https://colab.research.google.com/github/Tiffinysb3/Tiffinysb3/blob/master/Tiffiny's_Lab2_Conditionals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color="red">Important!</font>: As usual, make a copy of this notebook, put your name on the title, and share it with okeonwuka@gmail.com
# <font color="red"> For example, if your name is Mary Jane, you would make a copy of this notebook and change the title of your copy to "Mary_Jane_LabX- XXXXXXX"</font>![DALL·E 2024-06-17 20.04.54 - A person standing at a fork in the road, contemplating two distinct paths. One path leads to a bright, sunny landscape with green fields and a clear b.webp](data:image/webp;base64,...)

# %%
import random

day_in_the_week = ["Mon", "Tue", "Wed", "Thur", "Fri" ]

day = random.choice(day_in_the_week)

print(day)
# Out:
# Mon

# %%
import random

day_in_the_week = ["Mon", "Tue", ]
# day_in_the_week = ["Mon", "Tue", "Wed", "Thur", "Fri"]

day = random.choice(day_in_the_week)

print(day)
# Out:
# Mon

# %%
if day == "Tue":
  print("Taco Tuesday")

# %%
if day == 'Tue':
  print("Taco Tuesday")
elif day == 'Mon':
  print("We have class today")
# Out:
# We have class today

# %% [markdown]
# # **Introduction**
#
# ### Conditionals are <i>Code Paths</i>
#
# In Python, all decisions are made through three keywords: <tt>**if**</tt>, <tt>**elif**</tt>, and <tt>**else**</tt>
# + These allow you to make decisions based on the value of data
# + And those decisions can direct code to take different actions.
#
# These control structures are called ***conditionals***

# %% [markdown]
# In Python, **if**, **elif**, and **else** are used for making decisions in your code based on certain conditions. Here's when and how to use each one:

# %% [markdown]
# # **if**

# %% [markdown]
# Use **if** when you want to check a condition ***for the first time***. It's the starting point for a decision. Assuming the condition after the **if** statment is <font color="purple">True</font>, the code block under **if** statment gets executed. On the other hand, assuming the condition is <font color="purple">False</font>, the code block is skipped. Example:

# %%
if condition1:
    # Code to execute if condition1 is True
# Out:
#   File "/tmp/ipython-input-2756036639.py", line 2
#     # Code to execute if condition1 is True
#                                            ^
# SyntaxError: incomplete input

# %% [markdown]
# # **elif**

# %% [markdown]
# **elif** (short for "else if"): Use **elif** after an **if-block to check additional conditions assuming the previous conditions were** <font color="purple">False</font>. You can have multiple **elif-blocks** to check multiple conditions in sequence. **elif** only gets checked when the previous **if** or **elif** conditions were <font color="purple">False</font>. Example:

# %%
if condition1:
    # Code to execute if condition1 is True
elif condition2:
    # Code to execute if condition1 is False but condition2 is True
elif condition3:
    # Code to execute if condition1 and condition2 are False but condition3 is True

# %% [markdown]
# # **else**

# %% [markdown]
# **else**: Use **else** at the end of an **if-elif chain** to define what should happen when **none of the previous conditions were** <font color="purple">True</font>. The **else-block** does not have a condition; it catches everything that wasn't caught by the preceding **if** or **elif-blocks**. There can only be one **else** block, and it's always the last part of the decision structure. Example:

# %%
if condition1:
    # Code to execute if condition1 is True
elif condition2:
    # Code to execute if condition1 is False but condition2 is True
else:
    # Code to execute if none of the above conditions are True

# %% [markdown]
# # **Examples**

# %% [markdown]
# ## For our examples, we will make use our trusty "random" module

# %%
import random

day_in_the_week = ["Mon","Tue","Wed"]
# day_in_the_week = ["Mon","Tue","Wed","Thur","Fri"]

day = random.choice(day_in_the_week)

print(day)

# %% [markdown]
# # **Example of 'if' conditional**

# %%
if day == "Tue":
  print("Taco Tuesday")

# %% [markdown]
# # **Example of 'if - elif' conditional**

# %%
if day == 'Tue':
  print("Taco Tuesday")
elif day == 'Mon':
  print("We have class today")
elif day == 'Mon':
  print("We have class today")
elif day == 'Mon':
  print("We have class today")

# %% [markdown]
# # **Example of 'if - elif- else' conditional**

# %%
if day == 'Tue':
  print("Taco Tuesday")
elif day == 'Mon':
  print("We have class today")
else:
  print ("The day is none of these given days")

# %% [markdown]
# # <font color="darkblue"><b>Assignment: Rock Paper Scissors!</b></font>
#
#
# As an example of a conditional control structure, try the following cell.
#
# It plays a very unfair (and impolite) version of rock-paper-scissors:

# %%
# A very unfair game of rock-paper-scissors

user_name = input("What is your name? ")
print("Welcome,", user_name, "!")
print()

print("I challenge you to rock-paper-scissors! Prepare to be vanquished!")

user_choice = input("Which do you choose? (rock/paper/scissors):")
print()

if user_choice == "rock":
  print("You chose", user_choice)
  print("But I chose paper...")   # this doesn't seem fair...
  print("My paper smothers your rock!")

elif user_choice == "paper":
  print("You chose", user_choice, "?")
  print("I'm sorry: My scissors have confetti'd you!")

else:
  print("You chose", user_choice)
  print("Wow. You chose poorly!")
  print("I win.")


print()
print("Try again, if you dare...")

# %% [markdown]
# To Do
#
#
#
# ---
#
#
# Run the above cell several times...
# Try different inputs, including rock, paper, scissors, and some others. Experiment!
# In each case, consider the results...
#
#
#
#
# To Answer
#
#
# Feel free to include your answers here, just after each question. (A couple of these are completed as examples.)
#
# In the above cell, which lines run when user_choice is equal to rock?
# Answer: lines 13-15, the if block's body, are run in this case
# In the above cell, which lines run when user_choice is equal to paper?
# Answer:lines 18-19, the elif block's body, are run here
# In the above cell, which lines run when user_choice is equal to Rock?
# Answer:
# In the above cell, which lines run when user_choice is equal to POPTARTS!?
# Answer:
# If you delete just the if block (lines 12-15) entirely, how does the program's behavior change?
# Answer:
# What if you delete just the elif block (lines 17-19)?
# Answer:
# What if you delete just the else block (lines 21-24)?
# Answer:
# What if you change just the keyword elif to the keyword if on line 17? How does the program's behavior change?
# Answer:
#
# To Notice
#
#
# In the above cell, notice that to test if a variable is equal to a value, Python uses two equal signs
# user_choice == "rock" is a test
# On the other hand, to set a variable to a value, Python uses one equal sign
# user_choice = input("Which?") sets user_choice. (It's not a test.)
# The body of each conditional block is indented. This is how Python knows when the block ends.
# When its indentation ends, so does that block of code.

# %% [markdown]
# To Answer
# Feel free to include your answers here, just after each question. (A couple of these are completed as examples.)
#
# In the above cell, which lines run when user_choice is equal to rock?
# Answer: lines 13-15, the if block's body, are run in this case
# In the above cell, which lines run when user_choice is equal to paper?
# Answer:lines 18-19, the elif block's body, are run here
# In the above cell, which lines run when user_choice is equal to Rock?
#     Answer: Lines 13-15, 27-28
# In the above cell, which lines run when user_choice is equal to POPTARTS!?
#     Answer: Lines 21-24, 27-28
# If you delete just the if block (lines 12-15) entirely, how does the program's behavior change?
#     Answer:"rock" would no longer have a special case, it would instead trigger the else message.
# What if you delete just the elif block (lines 17-19)?
#     Answer:"paper" would trigger the else message. It would also trigger and error message of an unrecognized input.
# What if you delete just the else block (lines 21-24)?
#     Answer:no feedback would be given.
# What if you change just the keyword elif to the keyword if on line 17? How does the program's behavior change?
#     Answer:Nothing happens.
