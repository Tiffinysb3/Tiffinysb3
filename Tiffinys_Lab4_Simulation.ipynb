# %% [markdown]
# <a href="https://colab.research.google.com/github/Tiffinysb3/Tiffinysb3/blob/master/Tiffinys_Lab4_Simulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color="red">Important!</font>: As usual, make a copy of this notebook, put your name on the title, and share it with okeonwuka@gmail.com
#
# <font color="red"> For example, if your name is Mary Jane, you would make a copy of this notebook and change the title of your copy to "Mary_Jane_LabX- XXXXXXX"</font>

# %% [markdown]
# # **Introduction: Welcome to Simulations (aka Modeling)** 🤖

# %% [markdown]
# ## **What is Simulations (aka Modeling)**
# ### In computer science, **simulation** refers to the process of creating a **model** of a real-world or hypothetical situation or system, which can then be run on a computer to study the behavior and performance of the system under various conditions.
#
# ### This model can mimic the operation of the system over time, allowing researchers, engineers, and scientists to analyze, predict, or understand complex behaviors, processes, or phenomena without the need to experiment with the real system, which might be impractical, expensive, dangerous, or impossible.
#
# ### Simulations are used across many fields and applications, including:
# + ### **Engineering and Design:** To simulate structures, vehicles, electronics, and processes to predict performance before physical prototypes are built.
# + ### **Science and Research:** To study natural systems, weather patterns, astrophysical phenomena, or biological processes.
# + ### **Economics and Social Sciences:** To model economic systems, social networks, or population dynamics.
# + ### **Healthcare and Medicine:** For simulating surgeries, understanding the spread of diseases, or the biochemical processes within the human body.
# + ### **Entertainment and Education:** In video games, virtual reality environments, and educational software to create immersive learning experiences.
#
# ###  Simulations can range from simple models that approximate behaviors using a set of equations, to highly complex simulations that require massive computational resources, like those used for weather forecasting or simulating the human brain. Key components of a simulation in computer science include the model (the mathematical and logical representation of the system), the simulation engine (software that runs the model), and the user interface (which allows interaction with the simulation).

# %% [markdown]
# # **Monte Carlo Simulation**
# + ### These are ***actions*** that involve <font color="red">**repetitions**</font> and <font color="red">**randomness**</font>
# + ### that is, <font color="red">**loops**</font> and <font color="red">**conditions**</font>!

# %% [markdown]
# # **Example 1: Guessing Game**

# %% [markdown]
# ![download.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### The function below, named **guess**, is designed to simulate a computer attempting to guess a number that you've chosen, referred to as the "**hidden**" number, within a predefined range of 0 to 99 (inclusive). The function operates by repeatedly generating random guesses until it finds the hidden number. The core functionality of the function and how it operates is detailed below:
#
# ### **Function Overview**
# ###**Parameter/Argument**: The function takes a single parameter, hidden, which represents the number the computer is trying to guess.
#
# ###**Initial Setup**: It initializes two variables: guess is set to a value one less than hidden to ensure it starts with an incorrect guess, and number_of_guesses is set to 0 to track the number of guesses made.
#
# ###**Guessing Loop**: The function enters a while loop, where it continuously generates random numbers between 0 and 99 (inclusive) as guesses. For each iteration of the loop, it checks if the generated guess matches the hidden number.
#
# ###**Counting Guesses**: Each time the loop iterates, it increments the number_of_guesses counter by one, tracking how many guesses have been made.
#
# ###**Result**: Once the computer successfully guesses the hidden number (i.e., guess == hidden), the loop terminates, and the function returns a formatted string message. This message includes the total number of guesses it took for the computer to find the hidden number and what that number was.

# %%
#
# Example while loop: the "guessing game"
#

from random import *

def guess (hidden):
    """
        have the computer guess numbers until it gets the "hidden" value
        return the number of guesses
    """
    guess = hidden -1 # start with a wrong guess + don't count it as a guess
    number_of_guesses = 0 # start with no guesses made so far...


    while guess != hidden:
      guess = choice(range(0,100)) # 0 to 99, inclusive
      number_of_guesses = number_of_guesses + 1
    return f"Wow! The computer had to loop {number_of_guesses} times before it got the number I chose, which was {hidden}"


# test our function!
guess(90)

# Run guess function using other numbers eg guess(34), guess(6) etc. Have fun and play around with it. Make sure you understand the flow of execution.
# Out:
# 'Wow! The computer had to loop 164 times before it got the number I chose, which was 90'

# %% [markdown]
# # **Example 2: Rolling two dice and counting doubles**

# %% [markdown]
#  ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### The **count_doubles** function (see below), simulates rolling two six-sided dice a specified number of times (**num_rolls**) and counts how many of those rolls result in doubles, meaning both dice show the same value. This type of simulation is an example of a Monte Carlo simulation, which uses repeated random sampling to obtain numerical results. The function illustrates basic concepts in probability and statistics, as well as programming constructs like loops, conditional statements, and random number generation. Here's a breakdown of how the function works:
#
# ### **Function Overview**
# ###**Parameter**: num_rolls specifies how many times the dice should be rolled in the simulation.
#
# ###**Variable Initialization**: numdoubles is initialized to 0. This variable tracks the number of times both dice show the same value.
#
# ###**Looping Through Rolls**: The function uses a for loop to simulate dice rolls, iterating from 0 to num_rolls - 1. For each iteration (roll), it simulates rolling two dice.
#
# ###**Dice Rolling Simulation**:
# + ### d1 and d2 are variables that represent the outcome of rolling the first and second dice, respectively.
# + ### The outcomes are determined using the choice function from the random module, which selects a random value from the specified range (1 to 6 for a six-sided die).
#
# ###**Checking for Doubles**: Inside the loop, an if statement checks if the values of d1 and d2 are equal (i.e., a double). If they are, numdoubles is incremented by one, and a smiley face emoji ("🙂") is assigned to the variable you to indicate a double was rolled. Otherwise, you is set to a blank space.
#
# ###**Output**: For each roll, the function prints the roll number, the values of the two dice, and either a smiley face if a double was rolled or a blank space otherwise. This provides a visual representation of the simulation process and its outcomes.
#
# ###**Return Value**: After all rolls have been simulated, the function returns a formatted string that states the total number of doubles rolled during the simulation.

# %%
# Example Monte Carlo simulation: rolling two dice and counting doubles
#

from random import *


def count_doubles(num_rolls):
    """
        have the computer roll two six-sided dice, counting the # of doubles
        (same value on both dice)
        Then, return the number of doubles...
    """
    numdoubles = 0 # start with no doubles so far...

    for i in range(0,num_rolls): # roll repeatedly: i keeps track
      d1 = choice(range(1,7)) # 0 to 6, inclusive
      d2 = choice(range(1,7)) # 0 to 6, inclusive
      if d1 == d2:
        numdoubles+=1  # numdoubles = numdoubles + 1
        you = "🙂"
      else:
        you = ""
      print("run", i, "roll:", d1, d2, you)

    return f'The number of times the dice got doubles is {numdoubles} times'


count_doubles(100)
# Out:
# run 0 roll: 1 1 🙂
# run 1 roll: 1 6
# run 2 roll: 5 6
# run 3 roll: 3 5
# run 4 roll: 4 1
# run 5 roll: 3 5
# run 6 roll: 3 5
# run 7 roll: 1 5
# run 8 roll: 5 5 🙂
# run 9 roll: 5 5 🙂
# run 10 roll: 2 5
# run 11 roll: 5 4
# run 12 roll: 1 5
# run 13 roll: 6 3
# run 14 roll: 1 2
# run 15 roll: 1 1 🙂
# run 16 roll: 4 6
# run 17 roll: 2 1
# run 18 roll: 4 5
# run 19 roll: 2 3
# run 20 roll: 3 3 🙂
# run 21 roll: 4 1
# run 22 roll: 1 3
# run 23 roll: 1 4
# run 24 roll: 5 2
# run 25 roll: 1 5
# run 26 roll: 2 3
# run 27 roll: 1 6
# run 28 roll: 6 1
# run 29 roll: 3 4
# run 30 roll: 4 2
# run 31 roll: 3 3 🙂
# run 32 roll: 1 1 🙂
# run 33 roll: 3 1
# run 34 roll: 6 6 🙂
# run 35 roll: 5 6
# run 36 roll: 5 2
# run 37 roll: 3 6
# run 38 roll: 5 1
# run 39 roll: 3 1
# run 40 roll: 1 1 🙂
# run 41 roll: 1 6
# run 42 roll: 5 2
# run 43 roll: 4 5
# run 44 roll: 4 2
# run 45 roll: 3 2
# run 46 roll: 1 6
# run 47 roll: 6 6 🙂
# run 48 roll: 5 6
# run 49 roll: 2 2 🙂
# run 50 roll: 5 2
# run 51 roll: 6 4
# ...

# %% [markdown]
# # **Now, your turn: Counting triples!**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Your task is to modify the 'count_doubles' function above to count triples instead of doubles. This means your function will simulate rolling three six-sided dice and count how many times all three dice show the same value (triples).

# %% [markdown]
# ##**Instructions:**
#
# ###1. Create a new cell and copy 'count_doubles' function into that cell.
#
# ###2. Rename the Function: The new function should be named count_triples. This is to reflect the new functionality of counting triples instead of doubles.
#
# ###3. Adjust the Dice Rolling: In the original function, two dice are rolled. For your new function, you will need to simulate rolling three six-sided dice. Ensure you generate a random value for each of the three dice, representing each die's roll.
#
# ###4. Modify the Condition: Change the condition in the function to check if all three dice show the same value. In the original function, this was done for two dice. You need to extend this logic to encompass three dice.
#
# ###5. Update the Print Statement: Modify the print statement within your loop to display the results of all three dice rolls. Additionally, include an indicator (such as a smiley face 🙂) to show when a triple is rolled.
#
# ###6. Return Statement: Ensure your function returns a message that accurately reflects the number of triples rolled. For example, the message could be: 'The number of times the dice got triples is X times', where X is the number of triples.
#
# ##**Example of What to Change:**
#
# + ### You will change the part of the code that generates the dice rolls to include a third die (d3).
# + ### Adjust the if condition to compare three dice instead of two.
# + ### Update the print and return statements accordingly.
#
#
# ##**Deliverable:**
# ### Your final submission should be a Python function named count_triples that:
#
# + ### Takes num_rolls as an argument, representing the number of times to roll the three dice.
# + ### Rolls three six-sided dice for the specified number of times.
# + ### Counts and prints the number of times all three dice show the same value (triples).
# + ### Returns a string indicating the total number of triples found during the simulation.
# + ### Make sure your function is well-commented, explaining the purpose of each major step, and test your function to ensure it works correctly with various numbers of rolls.

# %%
# Example Monte Carlo simulation: rolling two dice and counting doubles
#

from random import *


def count_doubles(num_rolls):
    """
        have the computer roll two six-sided dice, counting the # of doubles
        (same value on both dice)
        Then, return the number of doubles...
    """
    numdoubles = 0 # start with no doubles so far...

    for i in range(0,num_rolls): # roll repeatedly: i keeps track
      d1 = choice(range(1,7)) # 0 to 6, inclusive
      d2 = choice(range(1,7)) # 0 to 6, inclusive
      if d1 == d2:
        numdoubles+=1  # numdoubles = numdoubles + 1
        you = "🙂"
      else:
        you = ""
      print("run", i, "roll:", d1, d2, you)

    return f'The number of times the dice got doubles is {numdoubles} times'


count_doubles(100)
# Out:
# run 0 roll: 1 1 🙂
# run 1 roll: 1 6
# run 2 roll: 5 6
# run 3 roll: 3 5
# run 4 roll: 4 1
# run 5 roll: 3 5
# run 6 roll: 3 5
# run 7 roll: 1 5
# run 8 roll: 5 5 🙂
# run 9 roll: 5 5 🙂
# run 10 roll: 2 5
# run 11 roll: 5 4
# run 12 roll: 1 5
# run 13 roll: 6 3
# run 14 roll: 1 2
# run 15 roll: 1 1 🙂
# run 16 roll: 4 6
# run 17 roll: 2 1
# run 18 roll: 4 5
# run 19 roll: 2 3
# run 20 roll: 3 3 🙂
# run 21 roll: 4 1
# run 22 roll: 1 3
# run 23 roll: 1 4
# run 24 roll: 5 2
# run 25 roll: 1 5
# run 26 roll: 2 3
# run 27 roll: 1 6
# run 28 roll: 6 1
# run 29 roll: 3 4
# run 30 roll: 4 2
# run 31 roll: 3 3 🙂
# run 32 roll: 1 1 🙂
# run 33 roll: 3 1
# run 34 roll: 6 6 🙂
# run 35 roll: 5 6
# run 36 roll: 5 2
# run 37 roll: 3 6
# run 38 roll: 5 1
# run 39 roll: 3 1
# run 40 roll: 1 1 🙂
# run 41 roll: 1 6
# run 42 roll: 5 2
# run 43 roll: 4 5
# run 44 roll: 4 2
# run 45 roll: 3 2
# run 46 roll: 1 6
# run 47 roll: 6 6 🙂
# run 48 roll: 5 6
# run 49 roll: 2 2 🙂
# run 50 roll: 5 2
# run 51 roll: 6 4
# ...

# %% [markdown]
# Tiffiny's Count-triples Function-

# %% [markdown]
# 1. I renamed the function
#
# From count_doubles → count_triples.
#
# Reason: function now counts triples, so the name should reflect that.
#
# 2. I renamed the counter variable
#
# From numdoubles → numtriples.
#
# Reason: keep variable name meaningful.
#
# 3. I added a third die roll
#
# Added d3 = choice(range(1, 7)).
#
# Reason: we now simulate three six-sided dice.
#
# 4. I changed the comparison condition
#
# From if d1 == d2: → if d1 == d2 == d3:.
#
# Reason: triple means all three values must be equal.
#
# 5. Next I updated the print statement
#
# From print("run", i, "roll:", d1, d2, you) → print("run", i, "roll:", d1, d2, d3, you).
#
# Reason: show the third die every run and indicate triples with the smiley.
#
# 6. Then I updated the return message
#
# From '...doubles is {numdoubles} times' → '...triples is {numtriples} times'.
#
# Reason: accurate result message.
#
# 7. Then I  did some minor cleanup / correctness
#
# I used choice(range(1,7)) and fixed the comment to say 1 to 6 inclusive (the original comment mistakenly said 0–6).
#
# 8. I changed the import to from random import choice (keeps it explicit and clearer).

# %%
# Your count_triples code here
from random import choice

def count_triples(num_rolls):
    """
    Roll three six-sided dice num_rolls times and count how many times
    all three dice show the same value (triples).
    """
    # start with zero triples counted
    numtriples = 0

    for i in range(num_rolls):
        # roll three dice (values 1 through 6)
        d1 = choice(range(1, 7))
        d2 = choice(range(1, 7))
        d3 = choice(range(1, 7))

        # check whether all three dice match
        if d1 == d2 == d3:
            numtriples += 1
            you = "🙂"   # indicator when a triple occurs
        else:
            you = ""

        # print results of this run including the third die
        print("run", i, "roll:", d1, d2, d3, you)

    # return a descriptive summary string
    return f'The number of times the dice got triples is {numtriples} times'

# example invocation
print(count_triples(100))
# Out:
# run 0 roll: 1 6 1
# run 1 roll: 1 4 6
# run 2 roll: 4 1 3
# run 3 roll: 2 5 1
# run 4 roll: 6 5 6
# run 5 roll: 4 2 4
# run 6 roll: 5 6 5
# run 7 roll: 5 6 5
# run 8 roll: 4 1 5
# run 9 roll: 3 2 3
# run 10 roll: 1 3 5
# run 11 roll: 6 5 3
# run 12 roll: 3 1 6
# run 13 roll: 4 1 1
# run 14 roll: 4 6 6
# run 15 roll: 5 4 4
# run 16 roll: 4 6 2
# run 17 roll: 3 5 6
# run 18 roll: 6 3 5
# run 19 roll: 1 1 6
# run 20 roll: 3 4 2
# run 21 roll: 1 6 3
# run 22 roll: 4 3 1
# run 23 roll: 5 2 6
# run 24 roll: 1 2 6
# run 25 roll: 2 6 1
# run 26 roll: 4 5 5
# run 27 roll: 5 3 6
# run 28 roll: 1 2 1
# run 29 roll: 2 2 4
# run 30 roll: 1 5 2
# run 31 roll: 2 5 4
# run 32 roll: 4 2 2
# run 33 roll: 2 1 3
# run 34 roll: 6 2 2
# run 35 roll: 3 5 3
# run 36 roll: 4 4 2
# run 37 roll: 2 2 1
# run 38 roll: 1 4 4
# run 39 roll: 5 4 3
# run 40 roll: 6 4 5
# run 41 roll: 6 5 6
# run 42 roll: 3 4 4
# run 43 roll: 5 2 4
# run 44 roll: 4 5 2
# run 45 roll: 6 6 6 🙂
# run 46 roll: 6 3 4
# run 47 roll: 4 1 1
# ...
